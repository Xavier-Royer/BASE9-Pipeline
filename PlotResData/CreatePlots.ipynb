# %%
import plot_mcmc as plot
import calc_plot_iso as iso_plot
# %load_ext autoreload
# %autoreload 2
#set cluster name here
cluster_name = "NGC_2420"

#create historgrams and scater of mcmc performance 
plot.createAllPlots(cluster_name)
#plot.createPlots("NGC_2360")

#creates iso plot
#iso_plot.create_iso_plot( mag="G", color="G_BP-G_RP", clusterName = cluster_name)
iso_plot.createAllCMDS(mag="G", color="G_BP-G_RP", root_dir = cluster_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Plots for version:
#   Plotting G vs. G_BP - G_RP CMD for 822 / 828 stars from NGC_2420/NGC_2420.phot.
#   File is cmd_iso.png.
# log(Age):  9.380 +/- 0.0006
# Age (Gry): 2.400 +/- 0.0031
# [Fe/H]:    -0.078 +/- 0.0027
# dist:      12.007 +/- 0.0025
# Av:        0.0678 +/- 0.0000
